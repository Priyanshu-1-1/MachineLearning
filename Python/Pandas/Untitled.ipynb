# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df= pd.read_csv("deliveries.csv")
df.shape
# Out:
# (193468, 18)

# %%
df.sample()
# Out:
#             id  inning  over  ball    batsman non_striker           bowler  \
# 108994  829705       2    13     3  G Gambhir    SA Yadav  Harbhajan Singh
#
#         batsman_runs  extra_runs  total_runs  non_boundary  is_wicket  \
# 108994             1           0           1             0          0
#
#        dismissal_kind player_dismissed fielder extras_type  \
# 108994            NaN              NaN     NaN         NaN
#
#                  batting_team    bowling_team
# 108994  Kolkata Knight Riders  Mumbai Indians

# %%
df.columns
# Out:
# Index(['id', 'inning', 'over', 'ball', 'batsman', 'non_striker', 'bowler',
#        'batsman_runs', 'extra_runs', 'total_runs', 'non_boundary', 'is_wicket',
#        'dismissal_kind', 'player_dismissed', 'fielder', 'extras_type',
#        'batting_team', 'bowling_team'],
#       dtype='object')

# %%
df.replace({'Rising Pune Supergiant':'Rising Pune Supergiants','Delhi Daredevils':'Delhi Capitals'},inplace=True)

# %%
df=df[df.is_wicket==1]
df.sample(2)
# Out:
#             id  inning  over  ball    batsman non_striker     bowler  \
# 103962  734009       1    19     2  RG Sharma  KA Pollard  SP Narine
# 37284   419147       2     4     4  MD Mishra    TL Suman   R Ashwin
#
#         batsman_runs  extra_runs  total_runs  non_boundary  is_wicket  \
# 103962             0           0           0             0          1
# 37284              0           0           0             0          1
#
#        dismissal_kind player_dismissed   fielder extras_type     batting_team  \
# 103962         bowled        RG Sharma       NaN         NaN   Mumbai Indians
# 37284         stumped        MD Mishra  MS Dhoni         NaN  Deccan Chargers
#
#                  bowling_team
# 103962  Kolkata Knight Riders
# 37284     Chennai Super Kings

# %% [markdown]
# ## Pivot Table

# %%
pt=df.pivot_table(index='over',columns="bowling_team",values="is_wicket",aggfunc='count')
pt
# Out:
# bowling_team  Chennai Super Kings  Deccan Chargers  Delhi Capitals  \
# over
# 0                              32               20              30
# 1                              38               20              53
# 2                              54               23              38
# 3                              44               22              47
# 4                              55               16              49
# 5                              48               18              51
# 6                              35               17              45
# 7                              32               13              37
# 8                              44               15              43
# 9                              37               16              47
# 10                             58               21              56
# 11                             49               19              41
# 12                             51               22              42
# ...

# %%
sns.heatmap(pt)
# Out:
# <Axes: xlabel='bowling_team', ylabel='over'>
